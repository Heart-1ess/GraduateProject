# %%
import pandas as pd
import numpy as np

# %%
file = "/home/zhangshuhao/projects/ys/Graduate/dataset/pheme_formatted.csv"
df = pd.read_csv(file)

# %%
df_true_rumour = df[(df['rumour_flag'] == 'rumour') & (df['veracity_label'] == 'true')]
df_false_rumour = df[(df['rumour_flag'] == 'rumour') & (df['veracity_label'] == 'false')]
df_unverified_rumour = df[(df['rumour_flag'] == 'rumour') & (df['veracity_label'] == 'unverified')]
df_true_non_rumour = df[(df['rumour_flag'] == 'non-rumour') & (df['veracity_label'] == 'true')]

# %%
df_true_rumour.head(10)
# Out:
#              topic rumour_flag  veracity_true  misinformation  \
# 19  ottawashooting      rumour            1.0             0.0
# 20  ottawashooting      rumour            1.0             0.0
# 21  ottawashooting      rumour            1.0             0.0
# 22  ottawashooting      rumour            1.0             0.0
# 23  ottawashooting      rumour            1.0             0.0
# 24  ottawashooting      rumour            1.0             0.0
# 25  ottawashooting      rumour            1.0             0.0
# 26  ottawashooting      rumour            1.0             0.0
# 27  ottawashooting      rumour            1.0             0.0
# 28  ottawashooting      rumour            1.0             0.0
#
#                                      category veracity_label  \
# 19  The soldier shot at War Memorial has died           true
# 20  The soldier shot at War Memorial has died           true
# 21  The soldier shot at War Memorial has died           true
# ...

# %%
df_false_rumour.head(1)
# Out:
#             topic rumour_flag  veracity_true  misinformation  \
# 0  ottawashooting      rumour            0.0             1.0
#
#                                             category veracity_label  \
# 0  There was a shooting incident near/at the Ride...          false
#
#    veracity_label_id           thread_id            tweet_id  parent_tweet_id  \
# 0                  0  524949073154301952  524949073154301952              NaN
#
#    ...  author_screen_name                      created_at  \
# 0  ...           grahamctv  Wed Oct 22 15:43:06 +0000 2014
#
#                                             text_raw  \
# 0  BREAKING: @ottawapolice confirm one death on P...
#
#                                           text_clean retweet_count  \
# 0  breaking ottawapolice confirm one death on par...           721
#
#    favorite_count  retweet_intensity  reply_count  depth  lang
# 0              53           0.714627            0      0    en
#
# [1 rows x 21 columns]

# %%
df_unverified_rumour.head(1)
# Out:
#               topic rumour_flag  veracity_true  misinformation  \
# 139  ottawashooting      rumour            0.0             0.0
#
#                                       category veracity_label  \
# 139  Suspect was a (Canadian) convert to Islam     unverified
#
#      veracity_label_id           thread_id            tweet_id  \
# 139                  2  525051210349289472  525051210349289472
#
#      parent_tweet_id  ...  author_screen_name                      created_at  \
# 139              NaN  ...             FoxNews  Wed Oct 22 22:28:58 +0000 2014
#
#                                               text_raw  \
# 139  Breaking News: U.S. agencies have been advised...
#
#                                             text_clean retweet_count  \
# 139  breaking news us agencies have been advised th...           443
#
#      favorite_count  retweet_intensity  reply_count  depth  lang
# 139             138           0.661839            0      0    en
#
# [1 rows x 21 columns]

# %%
df_true_non_rumour.head(1)
# Out:
#                topic rumour_flag  veracity_true  misinformation category  \
# 6436  ottawashooting  non-rumour            NaN             NaN      NaN
#
#      veracity_label  veracity_label_id           thread_id  \
# 6436           true                  1  525007169956347904
#
#                 tweet_id  parent_tweet_id  ...  author_screen_name  \
# 6436  525007169956347904              NaN  ...          hadeelalsh
#
#                           created_at  \
# 6436  Wed Oct 22 19:33:58 +0000 2014
#
#                                                text_raw  \
# 6436  the @OttawaPolice just sent an email to #musli...
#
#                                              text_clean retweet_count  \
# 6436  the ottawapolice just sent an email to muslim ...           412
#
#       favorite_count  retweet_intensity  reply_count  depth  lang
# 6436             269            0.65398            0      0    en
#
# [1 rows x 21 columns]

# %%
df_source = df[df['is_source'] == 1]
df_source.head(10)
# Out:
#               topic rumour_flag  veracity_true  misinformation  \
# 0    ottawashooting      rumour            0.0             1.0
# 11   ottawashooting      rumour            0.0             1.0
# 19   ottawashooting      rumour            1.0             0.0
# 47   ottawashooting      rumour            1.0             0.0
# 50   ottawashooting      rumour            1.0             0.0
# 61   ottawashooting      rumour            0.0             1.0
# 70   ottawashooting      rumour            1.0             0.0
# 107  ottawashooting      rumour            1.0             0.0
# 108  ottawashooting      rumour            0.0             1.0
# 115  ottawashooting      rumour            0.0             1.0
#
#                                               category veracity_label  \
# 0    There was a shooting incident near/at the Ride...          false
# 11   There was a shooting incident near/at the Ride...          false
# ...

# %%
df_source.describe()
# Out:
#        veracity_true  misinformation  veracity_label_id     thread_id  \
# count    2033.000000     2402.000000        6425.000000  6.425000e+03
# mean        0.524840        0.265612           1.009183  5.396601e+17
# std         0.499505        0.441750           0.455774  2.354899e+16
# min         0.000000        0.000000           0.000000  4.982355e+17
# 25%         0.000000        0.000000           1.000000  5.249651e+17
# 50%         1.000000        0.000000           1.000000  5.444295e+17
# 75%         1.000000        1.000000           1.000000  5.531655e+17
# max         1.000000        1.000000           2.000000  5.815507e+17
#
#            tweet_id  parent_tweet_id  is_source  retweet_count  \
# count  6.425000e+03              0.0     6425.0    6425.000000
# mean   5.396601e+17              NaN        1.0     362.382568
# std    2.354899e+16              NaN        0.0    1917.506836
# min    4.982355e+17              NaN        1.0       1.000000
# ...

# %%
df_source.to_csv("/home/zhangshuhao/projects/ys/Graduate/dataset/pheme_source.csv", index=False)
